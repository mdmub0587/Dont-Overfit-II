# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd 'drive/My Drive/Self Case Study-1'
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Self Case Study-1
#  BestModel.sav	    Final.ipynb         SavedModel
#  data		    ML_Models.ipynb    'Untitled document.gdoc'
#  DL_Models.ipynb    preprocessing.sav
#  EDA_and_FE.ipynb   result

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import joblib
from sklearn.metrics import  roc_auc_score

# %% [markdown]
# # Import Dataset

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
submission = pd.read_csv('data/sample_submission.csv')
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (250, 302)
# (19750, 301)
# (19750, 2)

# %% [markdown]
# # Train Test Data

# %%
X = train.drop(['id','target'], axis=1)
y = train['target']
test = test.drop(['id'], axis=1)
print(X.shape, y.shape)
print(test.shape)
# Out:
# (250, 300) (250,)
# (19750, 300)

# %% [markdown]
# # FInal Function 1

# %%
def final_fun_1(X):
    scale = joblib.load('preprocessing.sav')
    X = scale.transform(X)
    clf = joblib.load('BestModel.sav')
    pred = clf.predict_proba(X)[:,1]
    return pred
final_fun_1(test)
# Out:
# array([0.71968847, 0.49190704, 0.57449107, ..., 0.32917925, 0.82161274,
#        0.255214  ])

# %% [markdown]
# # Final_Funstion 2

# %%
def final_fun_2(X,Y):
    Y_pred = final_fun_1(X)
    score = roc_auc_score(Y, Y_pred)
    return score
final_fun_2(X,y)
# Out:
# 0.9522222222222223
